# %%
from gurobipy import Model, GRB, quicksum
from jabr import build_constraint_matrix, convert_matrix_to_mosek
from loadcase import load_case
from numpy import real, imag

# %%
#case = load_case('cases/case5_renumber_tree.m')s2 = 2**.5
#case = load_case('cases/case15_v2.m')
#case = load_case('cases/case85_v2.m')
case = load_case('cases/case118_v2.m')
#case = load_case('cases/case_ieee30_tree.m')
#case = load_case('cases/case_ieee30_tree_v2.m')
G, B = case.G, case.B
P = real(case.demands)
Q = imag(case.demands)
branches = case.branch_list
n = len(case.demands)
vhat = case.vhat
s2 = 2**.5
gens = {}

# %%
#external_gens = {2:1.045, 5:1.01, 8:1.01, 11:1.082, 13:1.071}
external_gens = {1: 0.955, 4: 0.998, 6: 0.990, 8: 1.015, 10: 1.050, 12: 0.990, 15: 0.970, 18: 0.973, 19: 0.962, 24: 0.992, 25: 1.050, 26: 1.015, 27: 0.968, 31: 0.967, 32: 0.963, 34: 0.984, 36: 0.980, 40: 0.970, 42: 0.985, 46: 1.005, 49: 1.025, 54: 0.955, 55: 0.952, 56: 0.954, 59: 0.985, 61: 0.995, 62: 0.998, 65: 1.005, 66: 1.050, 69: 1.035, 70: 0.984, 72: 0.980, 73: 0.991, 74: 0.958, 76: 0.943, 77: 1.006, 80: 1.040, 85: 0.985, 87: 1.015, 89: 1.005, 90: 0.985, 91: 0.980, 92: 0.990, 99: 1.010, 100: 1.017, 103: 1.010, 104: 0.971, 105: 0.965, 107: 0.952, 110: 0.973, 111: 0.980, 112: 0.975, 113: 0.993, 116: 1.005}
gens = {case.i2e.index(g):v for g, v in external_gens.iteritems()}
for gen, v in sorted(gens.iteritems()):
    print('%3d %5.3f' % (gen, v))
# Out:
#   0 1.035
#   1 0.955
#   4 0.998
#   6 0.990
#   8 1.015
#  10 1.050
#  12 0.990
#  15 0.970
#  18 0.973
#  19 0.962
#  24 0.992
#  25 1.050
#  26 1.015
#  27 0.968
#  31 0.967
#  32 0.963
#  34 0.984
#  36 0.980
#  40 0.970
#  42 0.985
#  46 1.005
#  49 1.025
#  54 0.955
#  55 0.952
#  56 0.954
#  59 0.985
#  61 0.995
#  62 0.998
#  65 1.005
#  66 1.050
#  69 0.984
#  71 0.980
#  72 0.991
#  73 0.958
#  75 0.943
#  76 1.006
#  79 1.040
#  84 0.985
#  86 1.015
#  88 1.005
#  89 0.985
#  90 0.980
#  91 0.990
#  98 1.010
#  99 1.017
# 102 1.010
# 103 0.971
# 104 0.965
# 106 0.952
# 109 0.973
# 110 0.980
# 111 0.975
# 112 0.993
# 115 1.005

# %%
m = Model("jabr")
u = [m.addVar(name='u_%d'%i) for i in range(n)]
R = {(i, j): m.addVar(name='R_%d_%d' % (i, j)) for i, j in branches}
I = {(i, j): m.addVar(lb=-GRB.INFINITY, name='I_%d_%d' % (i, j)) for i, j in branches}
for i, j in branches:
    R[j, i] = R[i, j]
    I[j, i] = I[i, j]
m.update()
m.addConstr(u[0] == vhat*vhat/s2, 'u0')
for gen, v in gens.iteritems():
    m.addConstr(u[gen] == v*v/s2, 'u%d' % gen)
for i, j in branches:
    m.addQConstr(2*u[i]*u[j] >= R[i,j]*R[i,j] + I[i,j]*I[i,j], 'cone_%d_%d' % (i, j))
k = lambda i: (j for j in B[i, :].nonzero()[1])
s = lambda i, j: 1 if i < j else -1
for i in range(1, n):
    m.addConstr(-s2*u[i]*G[i, :].sum() + quicksum(G[i,j]*R[i,j] + B[i,j]*s(i,j)*I[i,j] for j in k(i)) == P[i],
                'real_flow_%d_%d' % (i, j))
    if i in gens:
        continue
    m.addConstr(s2*u[i]*B[i, :].sum() + quicksum(-B[i,j]*R[i,j] + G[i,j]*s(i,j)*I[i,j] for j in k(i)) == Q[i],
                'reac_flow_%d_%d' % (i, j))
m.setObjective(quicksum(R[i,j] for i, j in branches), sense=GRB.MAXIMIZE)
m.params.outputFlag = 0
#m.setParam('BarConvTol', 1e-1)
#m.setParam('DualReductions', 0)
#m.setParam('BarHomogeneous', 1)
m.optimize()
print(m.status)
# Out:
# 2

# %%
for i, x in enumerate(u):
    y = x.getAttr('x')
    print('%2d %f %.3f %d' % (i, (s2*y)**.5, y, 1 if i in gens else 0))
# Out:
#  0 1.035000 0.757 1
#  1 0.955000 0.645 1
#  2 0.980472 0.680 0
#  3 0.961572 0.654 0
#  4 0.998000 0.704 1
#  5 1.000238 0.707 0
#  6 0.990000 0.693 1
#  7 0.988690 0.691 0
#  8 1.015000 0.728 1
#  9 1.023043 0.740 0
# 10 1.050000 0.780 1
# 11 0.980390 0.680 0
# 12 0.990000 0.693 1
# 13 0.960078 0.652 0
# 14 0.986182 0.688 0
# 15 0.970000 0.665 1
# 16 0.948927 0.637 0
# 17 0.980796 0.680 0
# 18 0.973000 0.669 1
# 19 0.962000 0.654 1
# 20 0.919712 0.598 0
# 21 0.926202 0.607 0
# 22 0.945818 0.633 0
# 23 0.992908 0.697 0
# 24 0.992000 0.696 1
# 25 1.050000 0.780 1
# 26 1.015000 0.728 1
# 27 0.968000 0.663 1
# 28 0.948590 0.636 0
# 29 0.938225 0.622 0
# 30 0.987268 0.689 0
# 31 0.967000 0.661 1
# 32 0.963000 0.656 1
# 33 0.958661 0.650 0
# 34 0.984000 0.685 1
# 35 0.973965 0.671 0
# 36 0.980000 0.679 1
# 37 0.982412 0.682 0
# 38 0.978610 0.677 0
# 39 0.960911 0.653 0
# 40 0.970000 0.665 1
# 41 0.953767 0.643 0
# 42 0.985000 0.686 1
# 43 0.887454 0.557 0
# 44 0.920242 0.599 0
# 45 0.944878 0.631 0
# 46 1.005000 0.714 1
# 47 1.002062 0.710 0
# 48 1.015978 0.730 0
# 49 1.025000 0.743 1
# 50 1.011785 0.724 0
# 51 0.977020 0.675 0
# 52 0.970174 0.666 0
# 53 0.933770 0.617 0
# 54 0.955000 0.645 1
# 55 0.952000 0.641 1
# 56 0.954000 0.644 1
# 57 1.001990 0.710 0
# 58 0.971617 0.668 0
# 59 0.985000 0.686 1
# 60 0.992461 0.696 0
# 61 0.995000 0.700 1
# 62 0.998000 0.704 1
# 63 0.985913 0.687 0
# 64 0.992243 0.696 0
# 65 1.005000 0.714 1
# 66 1.050000 0.780 1
# 67 1.036778 0.760 0
# 68 1.010163 0.722 0
# 69 0.984000 0.685 1
# 70 0.986261 0.688 0
# 71 0.980000 0.679 1
# 72 0.991000 0.694 1
# 73 0.958000 0.649 1
# 74 0.954734 0.645 0
# 75 0.943000 0.629 1
# 76 1.006000 0.716 1
# 77 1.000077 0.707 0
# 78 1.011476 0.723 0
# 79 1.040000 0.765 1
# 80 1.020536 0.736 0
# 81 0.963628 0.657 0
# 82 0.962438 0.655 0
# 83 0.976994 0.675 0
# 84 0.985000 0.686 1
# 85 0.983921 0.685 0
# 86 1.015000 0.728 1
# 87 0.990531 0.694 0
# 88 1.005000 0.714 1
# 89 0.985000 0.686 1
# 90 0.980000 0.679 1
# 91 0.990000 0.693 1
# 92 0.980754 0.680 0
# 93 0.967956 0.663 0
# 94 0.947796 0.635 0
# 95 0.997081 0.703 0
# 96 1.029095 0.749 0
# 97 1.023089 0.740 0
# 98 1.010000 0.721 1
# 99 1.017000 0.731 1
# 100 0.952092 0.641 0
# 101 0.975669 0.673 0
# 102 1.010000 0.721 1
# 103 0.971000 0.667 1
# 104 0.965000 0.658 1
# 105 0.946465 0.633 0
# 106 0.952000 0.641 1
# 107 0.959310 0.651 0
# 108 0.957528 0.648 0
# 109 0.973000 0.669 1
# 110 0.980000 0.679 1
# 111 0.975000 0.672 1
# 112 0.993000 0.697 1
# 113 0.959951 0.652 0
# 114 0.958697 0.650 0
# 115 1.005000 0.714 1
# 116 0.971351 0.667 0
# 117 0.941883 0.627 0

# %%
ans = {}
for i, x in enumerate(u):
    y = x.getAttr('x')
    ans[case.i2e[i]] = y
for i in sorted(ans.keys()):
    y = ans[i]
    print('%f' % (s2*y)**.5, end=' ')
# Out:
# 0.955000 0.980472 0.961572 0.998000 1.000238 0.990000 0.988690 1.015000 1.023043 1.050000 0.980390 0.990000 0.960078 0.986182 0.970000 0.948927 0.980796 0.973000 0.962000 0.919712 0.926202 0.945818 0.992908 0.992000 1.050000 1.015000 0.968000 0.948590 0.938225 0.987268 0.967000 0.963000 0.958661 0.984000 0.973965 0.980000 0.982412 0.978610 0.960911 0.970000 0.953767 0.985000 0.887454 0.920242 0.944878 1.005000 1.002062 1.015978 1.025000 1.011785 0.977020 0.970174 0.933770 0.955000 0.952000 0.954000 1.001990 0.971617 0.985000 0.992461 0.995000 0.998000 0.985913 0.992243 1.005000 1.050000 1.036778 1.010163 1.035000 0.984000 0.986261 0.980000 0.991000 0.958000 0.954734 0.943000 1.006000 1.000077 1.011476 1.040000 1.020536 0.963628 0.962438 0.976994 0.985000 0.983921 1.015000 0.990531 1.005000 0.985000 0.980000 0.990000 0.980754 0.967956 0.947796 0.997081 1.029095 1.023089 1.010000 1.017000 0.952092 0.975669 1.010000 0.971000 0.965000 0.946465 0.952000 0.959310 0.957528 0.973000 0.980000 0.975000 0.993000 0.959951 0.958697 1.005000 0.971351 0.941883

# %%
for p, q in zip(P, Q):
    print('%7.3f %7.3f' % (p, q))
# Out:
#   0.000   0.000
# -18.300  -5.184
#   2.400   1.200
#   7.600   1.600
#  94.200 -13.590
#   0.000   0.000
#  22.800  10.900
#  30.000 -68.944
#   0.000   0.000
#   5.800   2.000
#   0.000 -26.019
#  11.200   7.500
#   0.000 -17.640
#   6.200   1.600
#   8.200   2.500
#   3.500   1.800
#   9.000   5.800
#   3.200   0.900
#   9.500   3.400
#   2.200   0.700
#  17.500  11.200
#   0.000   0.000
#   3.200   1.600
#   8.700   6.700
#   0.000   0.000
#   3.500   2.300
#   0.000   0.000
#   0.000   0.000
#   2.400   0.900
#  10.600   1.900
